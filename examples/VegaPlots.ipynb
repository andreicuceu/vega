# %%
import numpy as np
import matplotlib.pyplot as plt
from vega import VegaInterface

# %%
vega = VegaInterface("D:\\work\\run\\eboss_0.2\\tests\\main.ini")
# Out:
# INFO: reading input Pk d:\work\repo\dev\vega\vega\models\PlanckDR12\PlanckDR12.fits
# Reading data file D:\\work\\run\\eboss_0.2\\tests\\data\\cf_z_0_10-exp.fits
#
# Warning! Running full-shape without blinding.
# WARNING!!!: Using full-shape fit or scaling of the smooth cf component. Sailor you are reaching unexplored territories, precede at your own risk.
# C:\Users\Andrei\anaconda3\envs\vega\lib\site-packages\mcfit\mcfit.py:157: UserWarning: input must be log-spaced
#   warnings.warn("input must be log-spaced")

# %%
model = vega.compute_model()
# Out:
# C:\Users\Andrei\anaconda3\envs\vega\lib\site-packages\mcfit\mcfit.py:217: UserWarning: The default value of extrap has been changed to False, set it to True if you cannot reproduce previous results
#   warnings.warn("The default value of extrap has been changed to False, "

# %% [markdown]
# ### Plot correlation as 1 wedge

# %%
vega.plots.plot_1wedge(models=[model]);

# %% [markdown]
# ### Plot correlations in 2 wedges

# %%
vega.plots.plot_2wedges(models=[model]);

# %% [markdown]
# ### Plot correlations in 4 wedges

# %%
vega.plots.plot_4wedges(models=[model]);
